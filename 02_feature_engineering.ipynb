# %% [markdown]
# # Feature Engineering – Maintenance prédictive (Valve)
#
# Objectif :
# - Extraire des caractéristiques statistiques par cycle
# - Construire un DataFrame final prêt pour le Machine Learning

# %%
import numpy as np
import pandas as pd
from pathlib import Path

# %%
DATA_DIR = Path("data/raw/condition+monitoring+of+hydraulic+systems")

SENSORS_100HZ = ["PS1","PS2","PS3","PS4","PS5","PS6","EPS1"]
SENSORS_10HZ  = ["FS1","FS2"]
SENSORS_1HZ   = ["TS1","TS2","TS3","TS4","VS1"]

SENSORS = SENSORS_100HZ + SENSORS_10HZ + SENSORS_1HZ

# %%
PROFILE_PATH = DATA_DIR / "profile.txt"

profile = pd.read_csv(
    PROFILE_PATH,
    delim_whitespace=True,
    header=None,
    encoding="latin1"
)

profile.shape
# Out:
# C:\Users\Alilou\AppData\Local\Temp\ipykernel_7212\3219860327.py:3: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   profile = pd.read_csv(
# (2205, 5)

# %%
profile.head()
# Out:
#    0    1  2    3  4
# 0  3  100  0  130  1
# 1  3  100  0  130  1
# 2  3  100  0  130  1
# 3  3  100  0  130  1
# 4  3  100  0  130  1

# %%
# cible binaire : 1 = valve OK (100%), 0 = défaut
valve_state = (profile.iloc[:, 1] == 100).astype(int)

valve_state.value_counts()
# Out:
# 1
# 1    1125
# 0    1080
# Name: count, dtype: int64

# %%
def load_sensor_matrix(sensor_name):
    path = DATA_DIR / f"{sensor_name}.txt"

    df = pd.read_csv(
        path,
        delim_whitespace=True,
        header=None,
        encoding="latin1"
    )

    # conversion explicite en float
    df = df.apply(pd.to_numeric, errors="coerce")

    return df

# %%
# Chargement de tous les capteurs dans un dictionnaire
sensor_data = {}

for sensor in SENSORS:
    df = load_sensor_matrix(sensor)
    sensor_data[sensor] = df
    print(f"{sensor} chargé : {df.shape}")
# Out:
# C:\Users\Alilou\AppData\Local\Temp\ipykernel_7212\84298602.py:4: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(
# C:\Users\Alilou\AppData\Local\Temp\ipykernel_7212\84298602.py:4: DtypeWarning: Columns (2908,2963,2984,2985,3038,3114,3132,3279,3335,3557,3610,3629,3632,3651,3692,3759,3851,3852,3904,3962,4117,4247,4253,4303,4395,4396,4412,4558,4613,4632,4634,4672,4763,4800,4949,5003,5078,5114,5188,5224,5242) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(
# PS1 chargé : (2205, 6000)
# C:\Users\Alilou\AppData\Local\Temp\ipykernel_7212\84298602.py:4: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(
# PS2 chargé : (2205, 6000)
# C:\Users\Alilou\AppData\Local\Temp\ipykernel_7212\84298602.py:4: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(
# PS3 chargé : (2205, 6000)
# C:\Users\Alilou\AppData\Local\Temp\ipykernel_7212\84298602.py:4: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(
# PS4 chargé : (2205, 6000)
# C:\Users\Alilou\AppData\Local\Temp\ipykernel_7212\84298602.py:4: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(
# PS5 chargé : (2205, 6000)
# C:\Users\Alilou\AppData\Local\Temp\ipykernel_7212\84298602.py:4: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(
# PS6 chargé : (2205, 6000)
# C:\Users\Alilou\AppData\Local\Temp\ipykernel_7212\84298602.py:4: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(
# EPS1 chargé : (2205, 6000)
# C:\Users\Alilou\AppData\Local\Temp\ipykernel_7212\84298602.py:4: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(
# FS1 chargé : (2205, 600)
# C:\Users\Alilou\AppData\Local\Temp\ipykernel_7212\84298602.py:4: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(
# FS2 chargé : (2205, 600)
# TS1 chargé : (2205, 60)
# TS2 chargé : (2205, 60)
# TS3 chargé : (2205, 60)
# C:\Users\Alilou\AppData\Local\Temp\ipykernel_7212\84298602.py:4: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(
# C:\Users\Alilou\AppData\Local\Temp\ipykernel_7212\84298602.py:4: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(
# C:\Users\Alilou\AppData\Local\Temp\ipykernel_7212\84298602.py:4: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(
# C:\Users\Alilou\AppData\Local\Temp\ipykernel_7212\84298602.py:4: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(
# TS4 chargé : (2205, 60)
# VS1 chargé : (2205, 60)
# C:\Users\Alilou\AppData\Local\Temp\ipykernel_7212\84298602.py:4: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(

# %%
def extract_features(signal):
    feats = {}

    feats["mean"] = np.mean(signal)
    feats["std"] = np.std(signal)
    feats["rms"] = np.sqrt(np.mean(signal**2))
    feats["iqr"] = np.percentile(signal, 75) - np.percentile(signal, 25)

    # temporel
    feats["trend"] = np.polyfit(np.arange(len(signal)), signal, 1)[0]
    feats["max_diff"] = np.max(np.abs(np.diff(signal)))
    feats["autocorr"] = np.corrcoef(signal[:-1], signal[1:])[0,1]
    feats["energy"] = np.sum(signal**2)

    # fréquentiel
    fft = np.abs(np.fft.rfft(signal))
    feats["dominant_freq"] = np.argmax(fft)
    feats["spectral_entropy"] = -np.sum((fft/fft.sum()) * np.log(fft/fft.sum() + 1e-12))

    return feats

# %%
import numpy as np

def extract_features(signal):
    feats = {}

    # statistiques
    feats["mean"] = np.mean(signal)
    feats["std"] = np.std(signal)
    feats["rms"] = np.sqrt(np.mean(signal**2))
    feats["iqr"] = np.percentile(signal, 75) - np.percentile(signal, 25)

    # temporelles
    feats["trend"] = np.polyfit(np.arange(len(signal)), signal, 1)[0]
    feats["max_diff"] = np.max(np.abs(np.diff(signal)))
    feats["autocorr"] = np.corrcoef(signal[:-1], signal[1:])[0, 1]
    feats["energy"] = np.sum(signal**2)

    # fréquentielles
    fft = np.abs(np.fft.rfft(signal))
    psd = fft / np.sum(fft)

    feats["dominant_freq"] = np.argmax(fft)
    feats["spectral_entropy"] = -np.sum(psd * np.log(psd + 1e-12))

    return feats

# %%
dataset_rows = []

n_cycles = sensor_data[SENSORS[0]].shape[0]

for cycle in range(n_cycles):
    row = {}

    for sensor in SENSORS:
        signal = sensor_data[sensor].iloc[cycle].values
        signal = np.nan_to_num(signal)

        feats = extract_features(signal)

        for k, v in feats.items():
            row[f"{sensor}_{k}"] = v

    row["valve_ok"] = valve_state.iloc[cycle]
    dataset_rows.append(row)

dataset = pd.DataFrame(dataset_rows)
dataset.shape
# Out:
# c:\Users\Alilou\.virtualenvs\Valve_Condition_Prediction-j2COp9es\Lib\site-packages\numpy\lib\_function_base_impl.py:3023: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# C:\Users\Alilou\AppData\Local\Temp\ipykernel_7212\1476750276.py:20: RuntimeWarning: invalid value encountered in divide
#   psd = fft / np.sum(fft)
# (2205, 141)

# %%
dataset.head()
# Out:
#      PS1_mean    PS1_std     PS1_rms  PS1_iqr  PS1_trend  PS1_max_diff  \
# 0  160.673492  13.938147  161.276914    15.12  -0.004043         14.75
# 1  160.603320  14.117791  161.222636    15.13  -0.004177          2.93
# 2  160.347720  14.191436  160.974495    15.28  -0.004211          3.06
# 3  160.188088  14.226617  160.818594    15.31  -0.004222          2.72
# 4  160.000472  14.275244  160.636028    15.30  -0.004249          3.08
#
#    PS1_autocorr    PS1_energy  PS1_dominant_freq  PS1_spectral_entropy  ...  \
# 0      0.999791  1.560615e+08                  0              1.834864  ...
# 1      0.999959  1.559564e+08                  0              1.331912  ...
# 2      0.999956  1.554767e+08                  0              1.348098  ...
# 3      0.999957  1.551757e+08                  0              1.347256  ...
# 4      0.999955  1.548236e+08                  0              1.361982  ...
#
#     VS1_std   VS1_rms  VS1_iqr  VS1_trend  VS1_max_diff  VS1_autocorr  \
# 0  0.026852  0.577575  0.05000  -0.000618         0.038      0.926329
# 1  0.027013  0.566494  0.03150  -0.000858         0.037      0.929533
# 2  0.036422  0.577683  0.04600  -0.001313         0.035      0.936527
# 3  0.033184  0.570233  0.04425  -0.000875         0.045      0.927742
# 4  0.033203  0.578321  0.04425  -0.001028         0.049      0.923011
#
#    VS1_energy  VS1_dominant_freq  VS1_spectral_entropy  valve_ok
# 0   20.015539                  0              0.576063         1
# 1   19.254955                  0              0.569901         1
# 2   20.023034                  0              0.665683         1
# 3   19.509942                  0              0.594516         1
# 4   20.067284                  0              0.599769         1
#
# [5 rows x 141 columns]

# %%
from pathlib import Path

PROCESSED_DIR = Path("data/processed")
PROCESSED_DIR.mkdir(parents=True, exist_ok=True)

dataset_path = PROCESSED_DIR / "dataset.csv"
dataset.to_csv(dataset_path, index=False)

dataset_path
# Out:
# WindowsPath('data/processed/dataset.csv')
